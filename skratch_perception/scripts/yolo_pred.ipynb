# %%
import os
import torch
from ultralytics import YOLO

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# trained_path = './../trained_models'
# name_path = 'go25_'
# trained_model_path = os.path.join(trained_path, name_path + '13', 'weights', 'best.pt')


# trained_model_path = "/home/bitbots/Downloads/rcaw25/trained_models/rcaw25_1/weights/best.pt"

trained_model_path = "/home/bitbots/Downloads/rcaw25/trained_models/rcaw25_2/weights/best.pt"

# test_path = './../dataset/gorcaw25_atWork/test/images'
# test_path = '/home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_2/images'

test_path = '/home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images'



# prediction_path = './../../../trained_predictions/pred_' + '10'
# prediction_path = '/home/bitbots/Downloads/rcaw25/inference'


prediction_path = '/home/bitbots/Downloads/rcaw25/model_eval'

! yolo obb predict model=$trained_model_path source=$test_path name=$prediction_path  exist_ok=True

# exis/home/bitbots/Downloads/rcaw25/inferencet_ok=True
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.9 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24154MiB)
# YOLOv8s-obb summary (fused): 81 layers, 11,418,537 parameters, 0 gradients, 29.5 GFLOPs
#
# image 1/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_00020.png: 480x640 39.2ms
# image 2/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_001003.png: 480x640 4.8ms
# image 3/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_001012.jpg: 480x640 4.2ms
# image 4/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_001051.jpg: 480x640 4.2ms
# image 5/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_001116.jpg: 480x640 4.2ms
# image 6/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_001152.png: 480x640 4.2ms
# image 7/60 /home/bitbots/Downloads/rcaw25/dataset/atWork_complete/test/images/atWork_001194.png: 480x640 4.2ms
# ...
