# %%
import os
import torch
from ultralytics import YOLO

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# trained_path = './../trained_models'
# name_path = 'go25_empty_'
# trained_model_path = os.path.join(trained_path, name_path + '2', 'weights', 'best.pt')

trained_model_path = '/home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/model/best_empty.pt'

# test_path = './../dataset/gorcaw25_atWork/test/images'
# test_path = '/home/bitbots/Downloads/gorcaw_25/dataset/atWork_empty_merged_go25/test/images'
test_path = '/home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/empty_space_images'

# prediction_path = './../../../trained_predictions/pred_empty' + '1'
prediction_path = '/home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/inference'

! yolo obb predict model=$trained_model_path source=$test_path name=$prediction_path exist_ok=True
# Out:
# WARNING ⚠️ conflicting 'task=obb' passed with 'task=detect' model. Ignoring 'task=obb' and updating to 'task=detect' to match model.
# Ultralytics 8.3.85 🚀 Python-3.11.9 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24154MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/49 /home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/empty_space_images/frame0000.jpg: 480x640 7 empty_spaces, 26.2ms
# image 2/49 /home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/empty_space_images/frame0001.jpg: 480x640 8 empty_spaces, 5.9ms
# image 3/49 /home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/empty_space_images/frame0002.jpg: 480x640 7 empty_spaces, 3.5ms
# image 4/49 /home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/empty_space_images/frame0003.jpg: 480x640 6 empty_spaces, 3.4ms
# image 5/49 /home/bitbots/Downloads/rcaw25/dataset/rcaw25_day_3/empty_space_images/frame0004.jpg: 480x640 10 empty_spaces, 3.5ms
# ...
